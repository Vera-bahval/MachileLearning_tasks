# %% [markdown]
# # 4.1 Линейная регрессия
#
# Вам предложен шаблон класса LinearRegression. Реализуйте методы  .fit() и .predict() соответствующие изложенной выше модели. В рамках выполнения этого задания можно пользоваться только библиотекой numpy. Использование любых других библиотек приведёт к ошибке при проверке задания автоматизированной системой. Также мы просим Вас не менять название класса и обозначенных методов, это также приведёт к ошибке. Добавлять свои методы в класс можно.
#
# Полученные коэффициенты модели должны храниться в поле .coef_
#
#
# Шаблон класса LinearRegression приведён ниже. Заполните все необходимые пропуски и отправьте получившийся файл в яндекс.контест. Не забудьте про все необходимые импорты.

# %%
import numpy as np
np.random.seed(42)

class LinearRegression:
    def __init__(self, **kwargs):
        self.coef_ = None
        pass

    def fit(self, x: np.array, y: np.array):
        # TODO: напишите метод .fit() класса LinearRegression
        x = np.vstack((np.ones((x.shape[0], )), x.T)).T
        Xt = np.transpose(x)
        XtX = np.dot(Xt,x)
        Xty = np.dot(Xt,y)
        beta = np.linalg.solve(XtX,Xty)
        beta_array = np.array(beta)
        self.coef_ = beta_array
        pass

    def predict(self, x: np.array):
        # TODO: напишите метод .predict(x) класса LinearRegression
        x = np.vstack((np.ones((x.shape[0], )), x.T)).T
        predictions = x.dot(self.coef_)
        return predictions

# %% [markdown]
# ## Примечания
#
# 1. Не забывайте добавлять столбец единиц (он нужен для добавления смещений).
# 2. При использовании различных матричных операций не забывайте проверять соответствие размерностей матриц-операндов. Не забывайте делать транспонирование там, где это требуется
# 3. Обращайте внимание на названия полей (self.coef_), методов (fit, predict) и порядка их параметров в предлагаемом шаблоне (см. выше). Сдаваемый на проверку код должен соответствовать предлагаемому шаблону.

# %% [markdown]
# ## Примеры входных и выходных данных

# %%
from sklearn.datasets import load_diabetes
from sklearn.model_selection import train_test_split

X, y = load_diabetes(return_X_y=True) #Этот датасет уже предобработан
print(X[:5])
# Out:
# [[ 0.03807591  0.05068012  0.06169621  0.02187239 -0.0442235  -0.03482076
#   -0.04340085 -0.00259226  0.01990749 -0.01764613]
#  [-0.00188202 -0.04464164 -0.05147406 -0.02632753 -0.00844872 -0.01916334
#    0.07441156 -0.03949338 -0.06833155 -0.09220405]
#  [ 0.08529891  0.05068012  0.04445121 -0.00567042 -0.04559945 -0.03419447
#   -0.03235593 -0.00259226  0.00286131 -0.02593034]
#  [-0.08906294 -0.04464164 -0.01159501 -0.03665608  0.01219057  0.02499059
#   -0.03603757  0.03430886  0.02268774 -0.00936191]
#  [ 0.00538306 -0.04464164 -0.03638469  0.02187239  0.00393485  0.01559614
#    0.00814208 -0.00259226 -0.03198764 -0.04664087]]

# %%
# Разбиение датасета на тренировочную и тестовую часть
X_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.3, shuffle=True, random_state=42)

# %%
print((X_train.transpose().dot(X_train)).shape)
# Out:
# (10, 10)

# %%
print((X_train.transpose().dot(X_train))**(-1))
# Out:
# [[  1.51321521  10.75840474   7.95337805   4.72612842   5.56359188
#     7.28183084 -63.18408655   8.6929528    5.37418283   5.53639055]
#  [ 10.75840474   1.42890618  31.32476326   8.58162679  41.716293
#    11.08198458  -4.1717677    4.3716721   11.67346518   8.84069063]
#  [  7.95337805  31.32476326   1.40084521   3.64514967   5.6535272
#     5.48670899  -3.81740879   3.20721415   3.122274     3.53056404]
#  [  4.72612842   8.58162679   3.64514967   1.40798639   5.79606502
#     8.55358796 -12.49896396   6.62850571   3.87836361   3.72568047]
#  [  5.56359188  41.716293     5.6535272    5.79606502   1.40532697
#     1.58005252  32.56549107   2.49432085   2.65701979   4.32116177]
#  [  7.28183084  11.08198458   5.48670899   8.55358796   1.58005252
#     1.41193299  -7.4724942    2.13320645   4.57716534   4.70069664]
#  [-63.18408655  -4.1717677   -3.81740879 -12.49896396  32.56549107
#    -7.4724942    1.4422571   -1.92213387  -3.66485572  -4.67551898]
#  [  8.6929528    4.3716721    3.20721415   6.62850571   2.49432085
#     2.13320645  -1.92213387   1.37568944   2.20904843   3.14009336]
#  [  5.37418283  11.67346518   3.122274     3.87836361   2.65701979
#     4.57716534  -3.66485572   2.20904843   1.40856275   3.01555076]
#  [  5.53639055   8.84069063   3.53056404   3.72568047   4.32116177
#     4.70069664  -4.67551898   3.14009336   3.01555076   1.40264795]]

# %%
# Создание объекта Вашего класса и его обучение
LinReg = LinearRegression()
LinReg.fit(X_train, y_train)
# print(X_train.transpose().shape)
# print(X_train.shape)
# print(y_train.shape)
# print((X_train.transpose().dot(y_train)).shape)
# print((X_train.transpose().dot(X_train)).shape)

# %%
# Прогноз на тестовом датасете
predictions = LinReg.predict(x_test)
predictions
# Out:
# array([138.46970031, 181.10052342, 125.34400904, 292.75977277,
#        123.8830531 ,  91.89830434, 257.26463123, 177.76169318,
#         84.98549706, 109.15960992,  94.4855284 , 166.13235108,
#         57.40742502, 206.13897354,  97.7811842 , 131.00472765,
#        214.29789972, 252.52907661, 199.66656381, 219.49985634,
#        203.23671317,  88.00656925,  70.65108459, 186.92233427,
#        155.81266751, 162.81022205, 191.93135706, 184.72924276,
#         46.62920829, 108.26566599, 178.14743952,  91.35065005,
#        127.72125745, 184.04205666, 172.23799897, 189.51548863,
#        121.83265708, 117.75339206, 145.67950306,  58.57563401,
#         72.55421321, 107.27571105, 166.15280313, 153.29339984,
#        165.19282154,  62.95752038,  73.58909449, 110.05656189,
#         54.49723354, 164.88920632, 152.49472803,  63.8874565 ,
#        111.4354561 , 108.34936269, 179.96973311, 158.70054112,
#         95.04833555, 209.68990406, 118.37356519,  69.69946093,
#        189.04680627, 204.99138626, 140.26840176, 105.75963198,
#        131.22316354, 201.65649349, 173.60251683, 164.25810664,
#        122.01567481, 143.53425629, 179.42286037, 201.32086534,
#        234.50804093, 146.96093984,  80.27567403, 160.86822173,
#        192.72110552, 208.6585054 , 158.56823462, 206.00933474,
#        111.53729194, 140.28763033,  51.15323818,  54.76434639,
#        113.02207773,  78.46425825,  80.20416459,  56.97774667,
#        168.51207071, 185.55749267, 152.33436369, 242.66080008,
#        106.44250735,  61.34968205,  53.44975218, 197.78538801,
#        246.62420102, 185.25237675, 105.80114548,  62.42547543,
#        193.39002547, 107.08821595, 297.08578592,  94.45306615,
#        148.41869832, 104.10666888, 128.66940497, 126.90012169,
#        165.84858396, 186.14546255, 108.5888133 , 203.83170771,
#        204.97622269, 209.10156998, 191.65509488, 161.26918179,
#        148.51075431, 135.0455994 , 111.74197539, 163.62966339,
#        170.55301782,  95.53608319,  46.85961143, 164.34533761,
#        127.1747026 , 176.61035076, 173.47305611, 107.40153597,
#        202.99778708,  92.10100436, 122.28876806,  80.80866991,
#        233.21870492])

# %%
# Оценка качества прогноза

from sklearn.metrics import r2_score

r2_score(y_test, predictions)
# Out:
# 0.47728971643226226

# %%
def r2(y_true, y_pred):
  d_e = 0
  d_z = 0
  y_mean = np.mean(y_true)
  for i in range(len(y_true)):
    d_e += (y_true[i] - y_pred[i])**2
    d_z += (y_true[i] - y_mean)**2
  return 1 - d_e/d_z
  #pass

# %%
print(r2(y_test, predictions))
# Out:
# 0.4772897164322619
